# %% [markdown]
# # • Impute numeric missing values using median/mode
# #   - The three numeric features in the original dataset (BMI, Height, Weight)
# #     were dropped entirely due to direct data leakage into our target (Obese).
# #   - The remaining features are all categorical and were already imputed
# #     using 'most_frequent' strategy inside the ColumnTransformer pipeline.
# #   - No further numeric imputation is required.
#
#
# # • One-hot encoding for nominal features
# #   - No nominal features exist in this dataset.
# #   - All categorical variables are either ordinal (Age_group, Education_level,
# #     Income_Cat) or binary (Sex, Smoker, Heavy_Drinker, Physical_Activity).
# #   - Ordinal features were encoded using OrdinalEncoder to preserve rank order.
# #   - Binary features were encoded as 0/1 using OrdinalEncoder.
# #   - One-hot encoding is not applicable here.
#
#
# # • Apply StandardScaler (mean=0, std=1)
# #   - StandardScaler is designed for continuous numeric features.
# #   - After dropping the leakage columns, no continuous features remain.
# #   - StandardScaler is not applicable here.
#
#
# # • Apply PCA to numeric features and compare variance explained
# #   - PCA requires continuous numeric features to produce meaningful components.
# #   - With only encoded categorical features remaining, PCA is no longer applicable here.
